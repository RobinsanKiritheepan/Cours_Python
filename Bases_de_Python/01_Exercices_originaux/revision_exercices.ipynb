# %% [markdown]
# # 🧠 Grand Notebook de Révision — Python (Day 1 → Day 5)
#
# Ce notebook reprend **tout le contenu du dossier `jupyter_notebook`** sous forme de petits exercices.
#
# **Comment l'utiliser :**
# 1. Fais les exercices dans l'ordre (ou pioche une partie).
# 2. Chaque exercice contient des `assert` : si la cellule s'exécute sans erreur et affiche ✅, c'est gagné !
# 3. Les solutions sont tout en bas, dans des blocs dépliants — essaie d'abord sans regarder 😉
#
# | Partie | Contenu révisé |
# |---|---|
# | 1 | Types, opérateurs, math, exceptions, conditions (Day 1) |
# | 2 | Strings, listes, boucles, fonctions, générateurs (Day 2) |
# | 3 | Dictionnaires, *args / **kwargs, POO (Day 3) |
# | 4 | enumerate, zip, décorateurs, matplotlib (Day 4) |
# | 5 | Pandas + le fichier `galaxy_park_data.csv` (Day 5) |

# %% [markdown]
# ## 🟦 Partie 1 — Types, opérateurs & compagnie (Day 1)

# %% [markdown]
# **Exercice 1.1 — Volume d'une sphère** 🪐
#
# Un ballon a un rayon de **3.2 m**. Calcule son volume avec la formule **V = (4/3) × π × r³**.
#
# Utilise `math.pi`, pas une valeur approchée !

# %%
import math

r = 3.2
volume = (4/3)*(math.pi)*(r**3) # TODO


print(f"Volume : {volume:.2f} m³")
assert round(volume, 2) == 137.26, "Presque ! Rappel : V = (4/3) * pi * r**3"
print("✅ Exercice 1.1 réussi !")
# Out:
# Volume : 137.26 m³
# ✅ Exercice 1.1 réussi !

# %% [markdown]
# **Exercice 1.2 — Division entière et modulo** ⏱️
#
# Une chanson dure **1000 secondes**. Avec `//` et `%`, convertis ça en minutes + secondes restantes.

# %%
total_secondes = 1000

minutes = 1000//60             # TODO
secondes_restantes = 1000%60  # TODO

print(f"{total_secondes} s = {minutes} min et {secondes_restantes} s")
assert minutes == 16 and secondes_restantes == 40
print("✅ Exercice 1.2 réussi !")
# Out:
# 1000 s = 16 min et 40 s
# ✅ Exercice 1.2 réussi !

# %% [markdown]
# **Exercice 1.3 — Opérateurs logiques** 🎢
#
# Pour monter dans l'attraction, il faut :
# - mesurer **au moins 140 cm**, OU
# - mesurer **au moins 120 cm** ET être **accompagné** d'un adulte.
#
# Écris une **seule expression** avec `and` / `or` (comme l'exercice de la bourse dans day1).

# %%
taille = 130
accompagne = True
peut_monter = (taille >= 140) or ((taille >= 120) and (accompagne == True))  # TODO : une seule expression logique
assert peut_monter == True

taille = 130
accompagne = False
peut_monter =  (taille >= 140) or ((taille >= 120) and (accompagne == True))  # TODO : recopie la même expression
assert peut_monter == False

taille = 145
accompagne = False
peut_monter =  (taille >= 140) or ((taille >= 120) and (accompagne == True))  # TODO : encore la même
assert peut_monter == True

print("✅ Exercice 1.3 réussi !")
# Out:
# ✅ Exercice 1.3 réussi !

# %% [markdown]
# **Exercice 1.4 — try / except** 🛡️
#
# Convertis chaque valeur de la liste en `int`. Si la conversion est impossible (`ValueError`), mets `0` à la place au lieu de planter.

# %%
valeurs = ["12", "7", "abc", "25", ""]
nombres = []

for v in valeurs:
    # TODO : essaie de convertir v en int et ajoute-le à nombres.
    # Si ça échoue (ValueError), ajoute 0 à la place.
    
    try:
        nombres.append(int(v))
    except:
        nombres.append(0)

print(nombres)
assert nombres == [12, 7, 0, 25, 0]
print("✅ Exercice 1.4 réussi !")
# Out:
# [12, 7, 0, 25, 0]
# ✅ Exercice 1.4 réussi !

# %% [markdown]
# **Exercice 1.5 — if / elif / else** 🎓
#
# Écris un bloc `if/elif/else` qui remplit la variable `mention` selon la note :
#
# | Note | Mention |
# |---|---|
# | ≥ 16 | Très bien |
# | ≥ 14 | Bien |
# | ≥ 12 | Assez bien |
# | ≥ 10 | Passable |
# | < 10 | Recalé |

# %%
note = 14.5

# TODO : ton bloc if/elif/else ici, qui remplit la variable `mention`
if (note >= 16):
    mention = "Très bien"
if (16 > note >= 14):
    mention = "Bien"
if (14 > note >= 12) :
    mention = "Assez bien"
if (note < 10 ) :
    mention = "Recalé"



print(f"Note {note} → {mention}")
assert mention == "Bien"
print("✅ Exercice 1.5 réussi ! (change la valeur de note pour tester les autres cas)")
# Out:
# Note 14.5 → Bien
# ✅ Exercice 1.5 réussi ! (change la valeur de note pour tester les autres cas)

# %% [markdown]
# ## 🟩 Partie 2 — Strings, listes, boucles & fonctions (Day 2)

# %% [markdown]
# **Exercice 2.1 — Nettoyage de chaîne** 🧹
#
# Avec `.strip()`, `.split()` et `.join()` :
# 1. transforme `brut` en une liste propre de langages ;
# 2. recolle-les avec `" | "` comme séparateur.

# %%
brut = "   python,java,c++   "

langages = (brut.strip()).split(",")  # TODO : strip puis split
print("langages : ", langages)
resultat = " | ".join(langages)  # TODO : join avec " | "
print("resultat : ", resultat)

print(langages)
print(resultat)
assert langages == ["python", "java", "c++"]
assert resultat == "python | java | c++"
print("✅ Exercice 2.1 réussi !")
# Out:
# langages :  ['python', 'java', 'c++']
# resultat :  python | java | c++
# ['python', 'java', 'c++']
# python | java | c++
# ✅ Exercice 2.1 réussi !

# %% [markdown]
# **Exercice 2.2 — Le piège de la mutabilité** ⚠️
#
# Ce code a un bug : modifier `copie` modifie aussi `original` ! Corrige **une seule ligne** pour que les asserts passent.

# %%
original = [10, 20, 30]
copie = original.copy()      # ← le bug est sur cette ligne !

copie[0] = 999

print("original :", original)
print("copie    :", copie)
assert original == [10, 20, 30], "original a été modifié... souviens-toi de .copy() !"
assert copie == [999, 20, 30]
print("✅ Exercice 2.2 réussi !")
# Out:
# original : [10, 20, 30]
# copie    : [999, 20, 30]
# ✅ Exercice 2.2 réussi !

# %% [markdown]
# **Exercice 2.3 — List comprehension** ⚡
#
# En **une seule ligne**, crée la liste des carrés des nombres **pairs** de 0 à 20 inclus.

# %%
carres_pairs = [n**2 for n in range(21) if (n%2) == 0]  # TODO : une seule ligne !

print(carres_pairs)
assert carres_pairs == [0, 4, 16, 36, 64, 100, 144, 196, 256, 324, 400]
print("✅ Exercice 2.3 réussi !")
# Out:
# [0, 4, 16, 36, 64, 100, 144, 196, 256, 324, 400]
# ✅ Exercice 2.3 réussi !

# %% [markdown]
# **Exercice 2.4 — Fonction moyenne** ➗
#
# Écris une fonction `moyenne(notes)` avec `sum()` et `len()`. Cas particulier : si la liste est vide, retourne `0` (sinon... `ZeroDivisionError` !).

# %%
def moyenne(notes):
    # TODO
    ...

assert moyenne([10, 15, 20]) == 15
assert moyenne([8]) == 8
assert moyenne([]) == 0
print("✅ Exercice 2.4 réussi !")

# %% [markdown]
# **Exercice 2.5 — Fibonacci récursif** 🌀
#
# C'est l'exercice resté en `TODO` dans day2 ! Écris `fib(n)` en version **récursive** (la fonction s'appelle elle-même) :
# - `fib(0) = 0`, `fib(1) = 1`
# - `fib(n) = fib(n-1) + fib(n-2)`

# %%
def fib(n):
    # TODO : version récursive
    ...

assert fib(0) == 0
assert fib(1) == 1
assert fib(10) == 55
print([fib(i) for i in range(11)])
print("✅ Exercice 2.5 réussi !")

# %% [markdown]
# **Exercice 2.6 — Générateur** ♻️
#
# Écris un générateur qui produit les multiples de 3 **strictement inférieurs** à `limite`. Utilise `yield`, pas `return` !

# %%
def multiples_de_3(limite):
    # TODO : utilise yield !
    ...

resultat = list(multiples_de_3(20))
print(resultat)
assert resultat == [0, 3, 6, 9, 12, 15, 18]
print("✅ Exercice 2.6 réussi !")

# %% [markdown]
# **Exercice 2.7 — Le nettoyeur de tweets** 🐦
#
# Aussi resté en `TODO` dans day2 ! Écris `nettoyer_tweet(tweet)` :
# 1. Enlève les espaces au début/fin (`.strip()`).
# 2. Si le tweet contient un mot interdit (`"scam"`, `"buy now"`, `"crypto"`), retourne `"[FLAGGED SPAM]"`. ⚠️ La détection doit marcher même en MAJUSCULES → pense à `.lower()`.
# 3. Sinon, retourne le tweet en minuscules avec les `"!"` remplacés par des `"."` (`.replace()`).

# %%
def nettoyer_tweet(tweet):
    # TODO
    ...

assert nettoyer_tweet("   BUY NOW to make millions!   ") == "[FLAGGED SPAM]"
assert nettoyer_tweet("I love programming in Python!!!   ") == "i love programming in python..."
assert nettoyer_tweet("Invest in crypto today") == "[FLAGGED SPAM]"
print("✅ Exercice 2.7 réussi !")

# %% [markdown]
# ## 🟨 Partie 3 — Dictionnaires & POO (Day 3)

# %% [markdown]
# **Exercice 3.1 — Inventaire de jeu** 🎒
#
# Manipule le dictionnaire `inventaire` :
# 1. Ajoute `"bouclier"` avec la valeur `2`.
# 2. Le joueur boit une potion → enlève 1 à `"potion"`.
# 3. Avec `.get()`, récupère le nombre de `"arc"` (valeur par défaut `0`, sans faire planter le programme).

# %%
inventaire = {"potion": 3, "epee": 1}

# TODO 1 : ajoute "bouclier" → 2

# TODO 2 : le joueur boit une potion

# TODO 3 : nombre de "arc" avec .get()
nb_arcs = ...

print(inventaire)
assert inventaire == {"potion": 2, "epee": 1, "bouclier": 2}
assert nb_arcs == 0
print("✅ Exercice 3.1 réussi !")

# %% [markdown]
# **Exercice 3.2 — Compteur de mots** 🔢
#
# Comme le compteur de fruits de day3 : découpe la phrase en mots avec `.split()` puis compte chaque mot dans le dictionnaire `compteur`.
#
# 💡 Astuce vue en cours : `compteur[mot] = compteur.get(mot, 0) + 1`

# %%
phrase = "le chat mange le poisson et le chien regarde le chat"
compteur = {}

# TODO : ta boucle ici


for mot, nb in compteur.items():
    print(f"Le mot '{mot}' apparaît {nb} fois")

assert compteur["le"] == 4
assert compteur["chat"] == 2
assert compteur["poisson"] == 1
print("✅ Exercice 3.2 réussi !")

# %% [markdown]
# **Exercice 3.3 — `*args`** 📦
#
# Écris `maximum_de(*nombres)` qui accepte un nombre quelconque d'arguments et retourne le plus grand, ou `None` s'il n'y a aucun argument.
#
# (Rappelle-toi le `multiply_all` de day3 — et son piège de la liste vide !)

# %%
def maximum_de(*nombres):
    # TODO
    ...

assert maximum_de(3, 9, 4) == 9
assert maximum_de(-5, -2, -10) == -2
assert maximum_de() is None
print("✅ Exercice 3.3 réussi !")

# %% [markdown]
# **Exercice 3.4 — `**kwargs`** 🗂️
#
# Écris `creer_personnage(nom, **caracteristiques)` qui retourne un dictionnaire `{"nom": nom}` complété avec toutes les caractéristiques passées en arguments nommés (comme le `build_profile` de day3).

# %%
def creer_personnage(nom, **caracteristiques):
    # TODO
    ...

p = creer_personnage("Kiri", force=10, magie=7)
print(p)
assert p == {"nom": "Kiri", "force": 10, "magie": 7}
assert creer_personnage("Bob") == {"nom": "Bob"}
print("✅ Exercice 3.4 réussi !")

# %% [markdown]
# **Exercice 3.5 — Ta première classe** 🏦
#
# Crée la classe `CompteBancaire` :
# - `__init__(self, titulaire, solde=0)` → attributs `titulaire` et `solde` ;
# - `deposer(self, montant)` → ajoute au solde ;
# - `retirer(self, montant)` → enlève du solde **seulement si** le solde est suffisant, sinon affiche `"Solde insuffisant !"` et ne change rien.

# %%
class CompteBancaire:
    # TODO : __init__, deposer, retirer
    ...

c = CompteBancaire("Kiri", 100)
c.deposer(50)
c.retirer(30)
c.retirer(1000)   # doit être refusé !
assert c.titulaire == "Kiri"
assert c.solde == 120
print("✅ Exercice 3.5 réussi !")

# %% [markdown]
# **Exercice 3.6 — Héritage** 🧬
#
# Crée `CompteEpargne` qui **hérite** de `CompteBancaire` :
# - `__init__(self, titulaire, solde, taux)` → utilise `super().__init__(...)` pour titulaire et solde, puis ajoute l'attribut `taux` ;
# - `appliquer_interets(self)` → augmente le solde de `solde * taux`.

# %%
class CompteEpargne(CompteBancaire):
    # TODO : __init__ avec super(), puis appliquer_interets
    ...

ce = CompteEpargne("Kiri", 1000, 0.05)
ce.appliquer_interets()
assert ce.solde == 1050
assert isinstance(ce, CompteBancaire)   # un CompteEpargne EST un CompteBancaire !
print("✅ Exercice 3.6 réussi !")

# %% [markdown]
# ## 🟧 Partie 4 — enumerate, zip, décorateurs & plots (Day 4)

# %% [markdown]
# **Exercice 4.1 — enumerate** 🏆
#
# Avec `enumerate(..., start=1)` et une f-string, remplis la liste `lignes` avec le classement : `"1. Alice"`, `"2. Bob"`, ...

# %%
finalistes = ["Alice", "Bob", "Charlie"]
lignes = []

# TODO : ta boucle avec enumerate ici


print(lignes)
assert lignes == ["1. Alice", "2. Bob", "3. Charlie"]
print("✅ Exercice 4.1 réussi !")

# %% [markdown]
# **Exercice 4.2 — zip** 🤐
#
# Avec `zip()`, combine les deux listes pour construire le dictionnaire `capitales` (comme l'exercice du menu dans day4).

# %%
villes = ["Paris", "Tokyo", "Lima"]
pays = ["France", "Japon", "Pérou"]

capitales = {}
# TODO : ta boucle avec zip ici


print(capitales)
assert capitales == {"Paris": "France", "Tokyo": "Japon", "Lima": "Pérou"}
print("✅ Exercice 4.2 réussi !")

# %% [markdown]
# **Exercice 4.3 — Décorateur** ⏱️
#
# Crée le décorateur `@chronometre` qui mesure le temps d'exécution d'une fonction :
# 1. note l'heure de départ avec `time.perf_counter()` ;
# 2. exécute la fonction et garde son résultat ;
# 3. affiche le temps écoulé ;
# 4. **retourne le résultat** (ne l'oublie pas !).
#
# 😉 Au passage : dans day4, ton `@simple_logger` affichait deux fois `"is starting..."` — le deuxième print aurait dû dire `"finished"` !

# %%
import time

def chronometre(fonction):
    # TODO : def wrapper(*args, **kwargs) ... return wrapper
    ...

@chronometre
def calcul_lent():
    return sum(range(1_000_000))

resultat = calcul_lent()
assert resultat == 499999500000, "Ton wrapper doit retourner le résultat de la fonction !"
print("✅ Exercice 4.3 réussi !")

# %% [markdown]
# **Exercice 4.4 — Matplotlib** 📈
#
# Trace les deux courbes de températures sur le **même graphique** :
# 1. `plt.figure(figsize=(10, 5))` ;
# 2. les 2 courbes avec `label=`, `marker=` et des couleurs différentes ;
# 3. titre `"Températures de la semaine"`, axe X `"Jour"`, axe Y `"Température (°C)"` ;
# 4. grille + légende ;
# 5. `plt.show()`.
#
# (Pas d'assert ici : la correction, c'est tes yeux 👀)

# %%
import matplotlib.pyplot as plt

jours = ["Lun", "Mar", "Mer", "Jeu", "Ven", "Sam", "Dim"]
temp_paris = [12, 14, 13, 16, 18, 21, 19]
temp_barcelone = [18, 19, 21, 22, 24, 26, 25]   # objectif été 2026 😎

# TODO : ton graphique ici

# %% [markdown]
# ## 🟥 Partie 5 — Pandas : retour au Galaxy Quest Outpost (Day 5)
#
# ⚠️ Le fichier `galaxy_park_data.csv` doit être dans le même dossier que ce notebook (c'est déjà le cas 👍).
#
# 💡 Si un assert de cette partie échoue après plusieurs exécutions, relance simplement depuis l'exercice 5.1 pour repartir d'un DataFrame propre.

# %% [markdown]
# **Exercice 5.1 — Charger et inspecter** 🔭
#
# Charge le CSV avec `pd.read_csv()`, affiche sa forme (`shape`) et ses 3 premières lignes (`head`).

# %%
import pandas as pd

park = ...  # TODO : charge "galaxy_park_data.csv"

print(f"Forme (lignes, colonnes) : {park.shape}")
display(park.head(3))
assert park.shape == (10, 8)
print("✅ Exercice 5.1 réussi !")

# %% [markdown]
# **Exercice 5.2 — Nouvelle colonne** 💸
#
# À cause de l'inflation spatiale, ajoute une colonne `"Credits_Avec_Taxe"` = `Credits_Spent` × **1.21** (21 % de taxe galactique).

# %%
# TODO : ajoute la colonne Credits_Avec_Taxe


display(park[["Visitor_Name", "Credits_Spent", "Credits_Avec_Taxe"]])
assert "Credits_Avec_Taxe" in park.columns
assert abs(park.loc[0, "Credits_Avec_Taxe"] - 545.105) < 0.01
print("✅ Exercice 5.2 réussi !")

# %% [markdown]
# **Exercice 5.3 — Filtrage multi-conditions** 🕵️
#
# Filtre les visiteurs dont `Ticket_Type` est `"VIP"` **ET** `Credits_Spent` > 300.
#
# 💡 Rappel : les deux conditions se combinent avec `&` et chaque condition va entre **parenthèses** !

# %%
vip_gros_depensiers = ...  # TODO

display(vip_gros_depensiers)
assert len(vip_gros_depensiers) == 3
print("✅ Exercice 5.3 réussi !")

# %% [markdown]
# **Exercice 5.4 — groupby** 👽
#
# Avec `groupby`, calcule la `Satisfaction_Score` **moyenne** par `Alien_Species`. Quelle espèce a l'air de saboter les avis ? 🤨

# %%
satisfaction_par_espece = ...  # TODO

print(satisfaction_par_espece)
assert round(satisfaction_par_espece["Human"], 2) == 7.87
print("✅ Exercice 5.4 réussi !")

# %% [markdown]
# **Exercice 5.5 — Valeurs manquantes (NaN)** 🩹
#
# 1. Compte combien de `Satisfaction_Score` sont manquants (`.isna().sum()`).
# 2. Remplace-les par la **moyenne** de la colonne (`.fillna()`).

# %%
# TODO 1 : compte les scores manquants
nb_manquants = ...

# TODO 2 : remplace les NaN par la moyenne de la colonne
park["Satisfaction_Score"] = ...

print(f"Scores manquants avant : {nb_manquants}")
assert nb_manquants == 2, "(si tu as déjà exécuté cette cellule, relance depuis le 5.1 !)"
assert park["Satisfaction_Score"].isna().sum() == 0
assert round(park.loc[4, "Satisfaction_Score"], 4) == 7.6875   # l'ancienne case vide de Xylar
print("✅ Exercice 5.5 réussi ! Révision terminée 🎉🎉🎉")

# %% [markdown]
# ---
#
# ## 🔑 Solutions
#
# Clique sur un bloc pour le déplier. Essaie d'abord sans regarder !

# %% [markdown]
# <details>
# <summary><b>👉 Solutions Partie 1</b></summary>
#
# ```python
# # 1.1
# import math
# volume = (4/3) * math.pi * 3.2**3
#
# # 1.2
# minutes = total_secondes // 60
# secondes_restantes = total_secondes % 60
#
# # 1.3
# peut_monter = (taille >= 140) or (taille >= 120 and accompagne)
#
# # 1.4
# for v in valeurs:
#     try:
#         nombres.append(int(v))
#     except ValueError:
#         nombres.append(0)
#
# # 1.5
# if note >= 16:
#     mention = "Très bien"
# elif note >= 14:
#     mention = "Bien"
# elif note >= 12:
#     mention = "Assez bien"
# elif note >= 10:
#     mention = "Passable"
# else:
#     mention = "Recalé"
# ```
#
# </details>

# %% [markdown]
# <details>
# <summary><b>👉 Solutions Partie 2</b></summary>
#
# ```python
# # 2.1
# langages = brut.strip().split(",")
# resultat = " | ".join(langages)
#
# # 2.2
# copie = original.copy()
#
# # 2.3
# carres_pairs = [x**2 for x in range(21) if x % 2 == 0]
#
# # 2.4
# def moyenne(notes):
#     if len(notes) == 0:
#         return 0
#     return sum(notes) / len(notes)
#
# # 2.5
# def fib(n):
#     if n <= 1:
#         return n
#     return fib(n - 1) + fib(n - 2)
#
# # 2.6
# def multiples_de_3(limite):
#     n = 0
#     while n < limite:
#         yield n
#         n += 3
#
# # 2.7
# def nettoyer_tweet(tweet):
#     tweet = tweet.strip()
#     minuscule = tweet.lower()
#     for mot_interdit in ["scam", "buy now", "crypto"]:
#         if mot_interdit in minuscule:
#             return "[FLAGGED SPAM]"
#     return minuscule.replace("!", ".")
# ```
#
# </details>

# %% [markdown]
# <details>
# <summary><b>👉 Solutions Partie 3</b></summary>
#
# ```python
# # 3.1
# inventaire["bouclier"] = 2
# inventaire["potion"] -= 1
# nb_arcs = inventaire.get("arc", 0)
#
# # 3.2
# for mot in phrase.split():
#     compteur[mot] = compteur.get(mot, 0) + 1
#
# # 3.3
# def maximum_de(*nombres):
#     if len(nombres) == 0:
#         return None
#     return max(nombres)
#
# # 3.4
# def creer_personnage(nom, **caracteristiques):
#     profil = {"nom": nom}
#     profil.update(caracteristiques)
#     return profil
#
# # 3.5
# class CompteBancaire:
#     def __init__(self, titulaire, solde=0):
#         self.titulaire = titulaire
#         self.solde = solde
#
#     def deposer(self, montant):
#         self.solde += montant
#
#     def retirer(self, montant):
#         if montant > self.solde:
#             print("Solde insuffisant !")
#         else:
#             self.solde -= montant
#
# # 3.6
# class CompteEpargne(CompteBancaire):
#     def __init__(self, titulaire, solde, taux):
#         super().__init__(titulaire, solde)
#         self.taux = taux
#
#     def appliquer_interets(self):
#         self.solde += self.solde * self.taux
# ```
#
# </details>

# %% [markdown]
# <details>
# <summary><b>👉 Solutions Partie 4</b></summary>
#
# ```python
# # 4.1
# for position, nom in enumerate(finalistes, start=1):
#     lignes.append(f"{position}. {nom}")
#
# # 4.2
# for ville, p in zip(villes, pays):
#     capitales[ville] = p
#
# # 4.3
# def chronometre(fonction):
#     def wrapper(*args, **kwargs):
#         debut = time.perf_counter()
#         resultat = fonction(*args, **kwargs)
#         fin = time.perf_counter()
#         print(f"⏱️ '{fonction.__name__}' a pris {fin - debut:.4f} s")
#         return resultat
#     return wrapper
#
# # 4.4
# plt.figure(figsize=(10, 5))
# plt.plot(jours, temp_paris, label="Paris", color="royalblue", marker="o")
# plt.plot(jours, temp_barcelone, label="Barcelone", color="darkorange", marker="s", linestyle="--")
# plt.title("Températures de la semaine")
# plt.xlabel("Jour")
# plt.ylabel("Température (°C)")
# plt.grid(True, linestyle=":", alpha=0.6)
# plt.legend()
# plt.show()
# ```
#
# </details>

# %% [markdown]
# <details>
# <summary><b>👉 Solutions Partie 5</b></summary>
#
# ```python
# # 5.1
# park = pd.read_csv("galaxy_park_data.csv")
#
# # 5.2
# park["Credits_Avec_Taxe"] = park["Credits_Spent"] * 1.21
#
# # 5.3
# vip_gros_depensiers = park[(park["Ticket_Type"] == "VIP") & (park["Credits_Spent"] > 300)]
#
# # 5.4
# satisfaction_par_espece = park.groupby("Alien_Species")["Satisfaction_Score"].mean()
#
# # 5.5
# nb_manquants = park["Satisfaction_Score"].isna().sum()
# park["Satisfaction_Score"] = park["Satisfaction_Score"].fillna(park["Satisfaction_Score"].mean())
# ```
#
# </details>
